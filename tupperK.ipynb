# %%
#------------------
# imports
#------------------
import matplotlib.pyplot as plt
# %matplotlib inline
import cv2
import numpy as np
from core.kfinder import getImageData
#----------------
# data check
#----------------
h,w=17,106
data="ঈদ-মুবারাক"
img=getImageData(data)
plt.imshow(img)
plt.show()
img= cv2.resize(img,(106,17),fx=0, fy=0, interpolation = cv2.INTER_NEAREST)
img[img==255]=1
img= cv2.flip(img, 1)
binary_string="".join([str(i)for i in img.T.flatten()])
tupperK=int(binary_string,2)*17
print(f"The tupper self referential formula K value for {data} is: ")
print(tupperK)
# Out:
# The tupper self referential formula K value for ঈদ-মুবারাক is:
# ...
